# %%
# !pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 211 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 7.4 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 81 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 5.3 MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=67f85d1a9cc5f009fc89b203482f1a333f96c39245a5a2d81dce831022634026
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3357 sha256=cabfae0b105957526e3c2a5c4fbe5666168d14f4746bcb5621c30b16da787ae5
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398404 sha256=d408d444485e64c699a5eeeee07fa1d3e7e601cd015e72f511c353de9ee3cd5c
# ...

# %%
from newspaper import Article

# %%
url = 'https://www.ackama.com/what-we-think/the-best-way-to-store-your-dotfiles-a-bare-git-repository-explained/'
article = Article(url)

# %%
article.download()

# %%
article.html
# Out:
# '<!DOCTYPE html>\n<html class="no-js"\n  id="coreHtml"\n  data-toggler=".navigation--active"\n  lang="en-US">\n  <head> <script type="text/javascript">if(!gform){document.addEventListener("gform_main_scripts_loaded",function(){gform.scriptsLoaded=!0}),window.addEventListener("DOMContentLoaded",function(){gform.domLoaded=!0});var gform={domLoaded:!1,scriptsLoaded:!1,initializeOnLoaded:function(o){gform.domLoaded&&gform.scriptsLoaded?o():!gform.domLoaded&&gform.scriptsLoaded?window.addEventListener("DOMContentLoaded",o):document.addEventListener("gform_main_scripts_loaded",o)},hooks:{action:{},filter:{}},addAction:function(o,n,r,t){gform.addHook("action",o,n,r,t)},addFilter:function(o,n,r,t){gform.addHook("filter",o,n,r,t)},doAction:function(o){gform.doHook("action",o,arguments)},applyFilters:function(o){return gform.doHook("filter",o,arguments)},removeAction:function(o,n){gform.removeHook("action",o,n)},removeFilter:function(o,n,r){gform.removeHook("filter",o,n,r)},addHook:function(o,
# ...

# %%
article.authors
# Out:
# ['Towards Ai Editorial Team',
#  'Established In Pittsburgh',
#  'Pennsylvania',
#  'Us',
#  'Towards Ai Co. Is The World S Leading Ai',
#  'Technology Publication Focused On Diversity',
#  'Equity',
#  'Inclusion. We Aim To Publish Unbiased Ai',
#  'Technology-Related Articles',
#  'Be An Impartial Source Of Information. Read Thought-Leaders']

# %%
article.parse()

# %%
article.top_image
# Out:
# 'https://www.ackama.com/wp-content/uploads/2020/08/Screen-Shot-2020-08-03-at-3.54.01-PM-196x300.png'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
url = 'https://twitter.com/regalstreak/status/1504002017542430727'
article = Article(url)
article.download()
article.parse()
article.nlp()

# %%
article.keywords
# Out:
# ['javascript',
#  'enable',
#  'twittercom',
#  'list',
#  'disabled',
#  'supported',
#  'using',
#  'switch',
#  'help',
#  'browser']

# %%
article.top_image
# Out:
# 'https://abs.twimg.com/responsive-web/client-web-legacy/icon-svg.168b89d5.svg'

# %%
article.summary
# Out:
# ''
